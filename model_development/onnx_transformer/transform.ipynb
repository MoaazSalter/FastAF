# %%
from ultralytics import YOLO

MODEL_PATH = r"..\model_training\model_4_yolo11m_datasetv4\best.pt"
model = YOLO(MODEL_PATH) 

model.export(format="onnx")
# Out:
# Ultralytics 8.3.132  Python-3.11.3 torch-2.7.0+cpu CPU (AMD Ryzen 5 4600H with Radeon Graphics)
# YOLO11m summary (fused): 125 layers, 20,065,498 parameters, 0 gradients, 67.8 GFLOPs
#
# PyTorch: starting from 'best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 50, 8400) (38.7 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.52...
# ONNX: export success  5.9s, saved as 'best.onnx' (76.8 MB)
#
# Export complete (7.9s)
# Results saved to C:\Users\lenovo\Desktop\Final model deployment
# Predict:         yolo predict task=detect model=best.onnx imgsz=640
# Validate:        yolo val task=detect model=best.onnx imgsz=640 data=/content/FastAF-5/data.yaml
# Visualize:       https://netron.app
# 'best.onnx'
